# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("climateIndices.csv")

# %%
df.shape
# Out:
# (2893, 17)

# %%
print(df[:,1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9e474df05113> in <module>()
# ----> 1 print(df[:,1])
#
# NameError: name 'df' is not defined

# %%
#illustrating the SOI values
df.hist(column='SOI in (monthly)')
df.hist(column='SOI out (monthly)')
df.hist(column='SOI middate (monthly)')
df.hist(column='SOI average (monthly)')
plt.show()

# %%
#illustrating PNA values
df.hist(column='PNA in (daily)')
df.hist(column='PNA out (daily)')
df.hist(column='PNA middate (daily)')
df.hist(column='PNA average (daily)')
plt.show()

# %%
#illustrating AO values
df.hist(column='AO in (daily)')
df.hist(column='AO out (daily)')
df.hist(column='AO middate (daily)')
df.hist(column='AO average (daily)')
plt.show()
