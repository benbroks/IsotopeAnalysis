# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("cleaned.csv")

# %%
time = pd.to_datetime(data['middate'], format='%m/%d/%Y', errors='coerce')
data.describe()
# Out:
#         Unnamed: 0  SOI in (monthly)  SOI out (monthly)  \
# count  2893.000000       2888.000000        2888.000000
# mean   1446.000000          0.149429           0.138411
# std     835.281489          1.103174           1.110003
# min       0.000000         -2.990000          -2.990000
# 25%     723.000000         -0.660000          -0.660000
# 50%    1446.000000          0.010000           0.010000
# 75%    2169.000000          1.000000           0.900000
# max    2892.000000          3.020000           3.020000
#
#        SOI middate (monthly)  SOI average (monthly)  PNA in (daily)  \
# count            2887.000000            2887.000000     2888.000000
# mean                0.152193               0.146585        0.091908
# std                 1.130679               1.081867        0.802937
# min                -2.990000              -2.990000       -2.530000
# 25%                -0.660000              -0.660000       -0.475000
# ...

# %%
#california data
mark1 = 155
mark2 = 426
mark3 = 673
mark4 = 914
mark5 = 1045
mark6 = 1339
mark7 = 1403
mark8 = 1448
mark9 = 1582
mark10 = 1607
mark11 = 1664
#oregon data
mark12 = 1705
mark13 = 2054
#washington data
mark14 = 2529
mark15 = 2660
mark16 = 2775
mark17 = 2893

# %%
#california soi
column = data['SOI middate (monthly)']
plt.plot_date(time[0:mark11], column[0:mark11])
plt.show()
#oregon soi
plt.plot_date(time[mark11:mark13], column[mark11:mark13])
plt.show()
#washington soi
plt.plot_date(time[mark13:], column[mark13:])
plt.show()

# %%
#california pna
column = data['PNA middate (daily)']
plt.plot_date(time[0:mark11], column[0:mark11])
plt.show()
#oregon pna
plt.plot_date(time[mark11:mark13], column[mark11:mark13])
plt.show()
#washington pna
plt.plot_date(time[mark13:], column[mark13:])
plt.show()

# %%
#california pna
column = data['AO middate (daily)']
plt.plot_date(time[0:mark11], column[0:mark11])
plt.show()
#oregon pna
plt.plot_date(time[mark11:mark13], column[mark11:mark13])
plt.show()
#washington pna
plt.plot_date(time[mark13:], column[mark13:])
plt.show()

# %%
#california dxs
column = data['amount [mL]']
plt.plot_date(time[0:mark11], column[0:mark11])
plt.show()
#oregon dxs
plt.plot_date(time[mark11:mark13], column[mark11:mark13])
plt.show()
#washington dxs
plt.plot_date(time[mark13:], column[mark13:])
plt.show()

# %%
#california dD
column = data['dD']
plt.plot_date(time[0:mark11], column[0:mark11])
plt.show()
#oregon dxs
plt.plot_date(time[mark11:mark13], column[mark11:mark13])
plt.show()
#washington dxs
plt.plot_date(time[mark13:], column[mark13:])
plt.show()

# %%
#california dO
column = data['dO']
plt.plot_date(time[0:mark11], column[0:mark11])
plt.show()
#oregon dxs
plt.plot_date(time[mark11:mark13], column[mark11:mark13])
plt.show()
#washington dxs
plt.plot_date(time[mark13:], column[mark13:])
plt.show()
